# %%
import pandas as pd
water = pd.read_csv("C:/Users/김혜윤/Desktop/2023-02/다변량/기말보고서/water_potability.csv")
water.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
water.dropna(inplace=True)
len(water)
# Out:
# 2011

# %%
water.groupby('Potability').mean()
# Out:
#                   ph    Hardness        Solids  Chloramines     Sulfate  \
# Potability
# 0           7.067201  196.008440  21628.535122     7.107267  333.742928
# 1           7.113791  195.908341  22344.922883     7.174395  332.457832
#
#             Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# Potability
# 0             427.554342       14.400250        66.278712   3.955181
# 1             425.005423       14.294764        66.581596   3.991254

# %%
water.groupby('Potability').std()
# Out:
#                   ph   Hardness       Solids  Chloramines    Sulfate  \
# Potability
# 0           1.659106  30.717642  8461.108693     1.476577  36.398403
# 1           1.437623  35.301146  8891.547966     1.732796  47.446190
#
#             Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# Potability
# 0              79.882677        3.370196        15.931953   0.782984
# 1              81.950982        3.257917        16.297713   0.776408

# %%
water[['Potability']].value_counts()
# Out:
# Potability
# 0             1200
# 1              811
# Name: count, dtype: int64

# %%
1200 / 2011
# Out:
# 0.5967180507210343

# %%
water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2011 entries, 3 to 3271
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 157.1 KB

# %%
water.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler  # 표준화 패키지 라이브러리 
x = water[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity']]
x = StandardScaler().fit_transform(pd.DataFrame(x)) # x객체에 x를 표준화한 데이터를 저장
x = pd.DataFrame(x)

# %%
water = water.reset_index(drop=True)
water
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 3       363.266516       18.436524       100.341674   4.628771
# ...

# %%
water[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity']] = x
water
# Out:
#             ph  Hardness    Solids  Chloramines   Sulfate  Conductivity  \
# 0     0.782466  0.564114  0.011687     0.583804  0.574378     -0.783962
# 1     1.275463 -0.455653 -0.455835    -0.370947 -0.560480     -0.348429
# 2    -0.954835 -0.234614  0.790645     0.259104 -0.158911     -1.810063
# 3     1.994902  1.596951  0.790764     0.239248  1.467140     -1.770608
# 4     0.985323  0.226606 -0.954313    -1.622878 -0.726179      0.595858
# ...        ...       ...       ...          ...       ...           ...
# 2006  1.210411  0.584770 -0.693978    -0.528284 -0.492625     -0.447578
# 2007 -0.243774  0.347964 -0.540564     0.362137 -0.697038     -1.205321
# 2008  2.800492 -3.100365  1.767503     1.343596 -1.803476      0.165656
# 2009 -0.646160 -0.285317  0.488576     0.387023  0.302843     -0.131852
# 2010 -1.537172 -0.070075  2.970287     0.020386  0.648718      1.238006
#
#       Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
x.columns = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity']

# %%
from sklearn.decomposition import PCA
pca = PCA() # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(x)
columns = x.columns
principalDf = pd.DataFrame(data=printcipalComponents, columns = columns)

# %%
import matplotlib.pyplot as plt
## Principal 1 & 2 explain about 97.8% of variance
plt.rcParams['figure.figsize'] = (13, 7)
plt.plot(range(1, principalDf.shape[1]+1), pca.explained_variance_ratio_)
plt.xlabel("number of Principal Components", fontsize=12)
plt.ylabel("% of Variance Explained", fontsize=12)
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 4) # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(x)
columns = ['주성분 1', '주성분 2', '주성분 3', '주성분 4']
principalDf = pd.DataFrame(data=printcipalComponents, columns = columns)

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.4926585932000984
